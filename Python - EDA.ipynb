# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Assignment Operator

# %%
X = 5

X
# Out:
# 5

# %% [markdown]
# #### Arithmetic Operators

# %%
# Addition

2 + 3
# Out:
# 5

# %%
# Subtraction

4 - 3
# Out:
# 1

# %%
# Exponent or Power operator

2 ** 3
# Out:
# 8

# %%
# Multiplication 

2 * 3
# Out:
# 6

# %%
# Division

8 / 2
# Out:
# 4.0

# %%
# Division

8 / 3
# Out:
# 2.6666666666666665

# %%
# Integer Division

8 // 3
# Out:
# 2

# %%
# Modulo Operator

8 % 3
# Out:
# 2

# %% [markdown]
# #### Comparison Operators

# %%
 not(10 < 9)
# Out:
# True

# %%
10 > 9
# Out:
# True

# %%
10 == 10
# Out:
# True

# %%
11 >= 21
# Out:
# False

# %%
11 <= 21
# Out:
# True

# %%
11 <= 21 and 10 > 10
# Out:
# False

# %%
11 <= 21 or 10 > 10
# Out:
# True

# %% [markdown]
# #### Assignment Operator

# %%
A = 2

A
# Out:
# 2

# %%
# Shorthand form of A = A + 2

A += 2

A
# Out:
# 8

# %%
A *= 2

A
# Out:
# 16

# %% [markdown]
# #### Memebership Operator

# %%
'A' in ['X' , 'Y' , 'A' , 'Z']
# Out:
# True

# %%
'B' in ['X' , 'Y' , 'A' , 'Z']
# Out:
# False

# %%
'B' not in ['X' , 'Y' , 'A' , 'Z']
# Out:
# True

# %%
'A' not in ['X' , 'Y' , 'A' , 'Z']
# Out:
# False

# %% [markdown]
# #### Identity Operators

# %%
List_Var = [ 1, 2, 3 ,4 ]

List_Var_2 = List_Var

List_Var_2 is List_Var
# Out:
# True

# %%
List_Var_3 = List_Var.copy()

List_Var_3 is List_Var
# Out:
# False

# %%
'Rock ' + 'Star'
# Out:
# 'Rock Star'

# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

# %%
Iris_DF = pd.read_csv('Iris.csv')

# %%
Iris_DF.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
del Iris_DF['Id']

# %%
Iris_DF.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Iris_DF.shape
# Out:
# (150, 5)

# %%
Iris_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
Iris_DF.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
Iris_DF.Species.describe()
# Out:
# count                150
# unique                 3
# top       Iris-virginica
# freq                  50
# Name: Species, dtype: object

# %%
Iris_DF.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
Iris_DF.Species.value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %%
plt.pie(Iris_DF.Species.value_counts() , labels = Iris_DF.Species.unique() , 
        autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x296ae581240>,
# ...
#  [Text(0.5499999702695115, 0.9526279613277875, 'Iris-setosa'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'Iris-versicolor'),
#   Text(0.5500001486524352, -0.9526278583383436, 'Iris-virginica')],
#  [Text(0.2999999837833699, 0.5196152516333385, '33.3%'),
#   Text(-0.5999999999999974, -5.6176054134900006e-08, '33.3%'),
#   Text(0.30000008108314646, -0.5196151954572783, '33.3%')])

# %%
plt.bar( Iris_DF.Species.unique() , Iris_DF.Species.value_counts() )
# Out:
# <BarContainer object of 3 artists>

# %%
plt.hist(Iris_DF.SepalLengthCm , bins=20)
# Out:
# (array([ 4.,  5.,  7., 16.,  9.,  5., 13., 14., 10.,  6., 10., 16.,  7.,
#         11.,  4.,  2.,  4.,  1.,  5.,  1.]),
#  array([4.3 , 4.48, 4.66, 4.84, 5.02, 5.2 , 5.38, 5.56, 5.74, 5.92, 6.1 ,
#         6.28, 6.46, 6.64, 6.82, 7.  , 7.18, 7.36, 7.54, 7.72, 7.9 ]),
#  <a list of 20 Patch objects>)

# %%
Iris_DF.iloc[ :, 0:4].boxplot()

# %% [markdown]
# ## Missing Value Processing

# %%
Cricket_Wins = { 'India' : [10,23,11,19,21],
                   'Australia' :[10,23,0,19,21],
                   'England' : [10,23,0,0,0],
                   'Pakistan': [9,15,8,12,17] }

Cricket_Wins_DF = pd.DataFrame(Cricket_Wins)

# %%
Cricket_Wins_DF
# Out:
#    India  Australia  England  Pakistan
# 0     10         10       10         9
# 1     23         23       23        15
# 2     11          0        0         8
# 3     19         19        0        12
# 4     21         21        0        17

# %%
Cricket_Wins_DF.describe()
# Out:
#            India  Australia    England   Pakistan
# count   5.000000   5.000000   5.000000   5.000000
# mean   16.800000  14.600000   6.600000  12.200000
# std     5.932959   9.555103  10.139033   3.834058
# min    10.000000   0.000000   0.000000   8.000000
# 25%    11.000000  10.000000   0.000000   9.000000
# 50%    19.000000  19.000000   0.000000  12.000000
# 75%    21.000000  21.000000  10.000000  15.000000
# max    23.000000  23.000000  23.000000  17.000000

# %%
(Cricket_Wins_DF == 0)
# Out:
#    India  Australia  England  Pakistan
# 0  False      False    False     False
# 1  False      False    False     False
# 2  False       True     True     False
# 3  False      False     True     False
# 4  False      False     True     False

# %%
# Find the number of instances in each column containing Zero values 

(Cricket_Wins_DF == 0).sum()
# Out:
# India        0
# Australia    1
# England      3
# Pakistan     0
# dtype: int64

# %%
Cricket_Wins_DF.replace(0,np.NaN , inplace = True)

# %%
Cricket_Wins_DF
# Out:
#    India  Australia  England  Pakistan
# 0     10       10.0     10.0         9
# 1     23       23.0     23.0        15
# 2     11        NaN      NaN         8
# 3     19       19.0      NaN        12
# 4     21       21.0      NaN        17

# %%
Cricket_Wins_DF.isnull()
# Out:
#    India  Australia  England  Pakistan
# 0  False      False    False     False
# 1  False      False    False     False
# 2  False       True     True     False
# 3  False      False     True     False
# 4  False      False     True     False

# %%
Cricket_Wins_DF.isnull().sum()
# Out:
# India        0
# Australia    1
# England      3
# Pakistan     0
# dtype: int64

# %%
Cricket_Wins_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
# India        5 non-null int64
# Australia    4 non-null float64
# England      2 non-null float64
# Pakistan     5 non-null int64
# dtypes: float64(2), int64(2)
# memory usage: 240.0 bytes

# %%
Cricket_Wins_DF_2 = Cricket_Wins_DF.copy()

# %%
Cricket_Wins_DF.dropna()
# Out:
#    India  Australia  England  Pakistan
# 0     10       10.0     10.0         9
# 1     23       23.0     23.0        15

# %%
Cricket_Wins_DF
# Out:
#    India  Australia  England  Pakistan
# 0     10       10.0     10.0         9
# 1     23       23.0     23.0        15
# 2     11        NaN      NaN         8
# 3     19       19.0      NaN        12
# 4     21       21.0      NaN        17

# %%
Cricket_Wins_DF.mean()
# Out:
# India        16.80
# Australia    18.25
# England      16.50
# Pakistan     12.20
# dtype: float64

# %%
Cricket_Wins_DF.fillna(Cricket_Wins_DF.mean())
# Out:
#    India  Australia  England  Pakistan
# 0     10      10.00     10.0         9
# 1     23      23.00     23.0        15
# 2     11      18.25     16.5         8
# 3     19      19.00     16.5        12
# 4     21      21.00     16.5        17

# %%
Cricket_Wins_DF.fillna(Cricket_Wins_DF.median())
# Out:
#    India  Australia  England  Pakistan
# 0     10       10.0     10.0         9
# 1     23       23.0     23.0        15
# 2     11       20.0     16.5         8
# 3     19       19.0     16.5        12
# 4     21       21.0     16.5        17

# %%
Cricket_Wins_DF['Played'] =['Outside' , 'Home',np.NaN , 'Outside',np.NaN]

# %%
Cricket_Wins_DF
# Out:
#    India  Australia  England  Pakistan   Played
# 0     10       10.0     10.0         9  Outside
# 1     23       23.0     23.0        15     Home
# 2     11        NaN      NaN         8      NaN
# 3     19       19.0      NaN        12  Outside
# 4     21       21.0      NaN        17      NaN

# %%
Cricket_Wins_DF['Played'].mode()
# Out:
# 0    Outside
# dtype: object

# %%
Cricket_Wins_DF['Played']
# Out:
# 0    Outside
# 1       Home
# 2        NaN
# 3    Outside
# 4        NaN
# Name: Played, dtype: object

# %%
Cricket_Wins_DF['Played'].fillna(Cricket_Wins_DF['Played'].mode()[0])
# Out:
# 0    Outside
# 1       Home
# 2    Outside
# 3    Outside
# 4    Outside
# Name: Played, dtype: object

# %%
Cricket_Wins_DF
# Out:
#    India  Australia  England  Pakistan   Played
# 0     10       10.0     10.0         9  Outside
# 1     23       23.0     23.0        15     Home
# 2     11        NaN      NaN         8      NaN
# 3     19       19.0      NaN        12  Outside
# 4     21       21.0      NaN        17      NaN

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = Cricket_Wins_DF.select_dtypes(include=numerics)

newdf
# Out:
#    India  Australia  England  Pakistan
# 0     10       10.0     10.0         9
# 1     23       23.0     23.0        15
# 2     11        NaN      NaN         8
# 3     19       19.0      NaN        12
# 4     21       21.0      NaN        17

# %%
newdf.columns
# Out:
# Index(['India', 'Australia', 'England', 'Pakistan'], dtype='object')

# %%
for col_na in newdf.columns:
    remove_outlier(newdf ,col_na)
